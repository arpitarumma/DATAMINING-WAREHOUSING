# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitarumma/DATAMINING-WAREHOUSING/blob/main/DMW3%264.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ord=pd.read_csv("/content/drive/MyDrive/Order_History.csv")
ord
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
cust=pd.read_csv("/content/drive/MyDrive/Customer_Info.csv")
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    15-06-1985        john.doe@email.com
# 1         C002      Jane Smith    11/20/1990      jane.smith@email.com
# 2         C003   Alice Johnson    05-09-1988   alice.johnson@email.com
# 3         C004     Michael Lee    20-07-1987     michael.lee@email.com
# 4         C005      Emma Davis    10-12-1992      emma.davis@email.com
# 5         C006    Robert Brown    1983-14-02    robert.brown@email.com
# 6         C007    Emily Wilson    19-07-1986    emily.wilson@email.com
# 7         C008    David Harris    25-05-1989    david.harris@email.com
# 8         C009  Linda Thompson           NaN  linda.thompson@email.com
# 9         C010     Paul Walker    30-08-1987     paul.walker@email.com
# 10        C002      Jane Smith    20-11-1990       janesmith@email.com
# 11        C011      Sarah Hall    22-04-1984                       NaN
# ...

# %%
duplicates = ord[ord.duplicated(keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Order_Date, Product, Quantity, Price, Name, Date_of_Birth, Email, Phone]
# Index: []

# %%
ord_column = set(ord.columns)
cust_column = set(cust.columns)

# %%
common_col = ord_column.intersection(cust_column)
print("Common columns:", common_col)
# Out:
# Common columns: {'Name', 'Phone', 'Email', 'Customer_ID', 'Date_of_Birth'}

# %%
duplicates = cust[cust.duplicated(keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Name, Date_of_Birth, Email, Phone]
# Index: []

# %%
print("\nMissing values in Customer_Info:")
print(cust.isnull().sum())
# Out:
# Missing values in Customer_Info:
# Customer_ID      0
# Name             0
# Date_of_Birth    1
# Email            1
# Phone            2
# dtype: int64

# %%
print("The missing values in order history")
ord=ord.isnull().sum()
ord
# Out:
# The missing values in order history
# Order_ID         0
# Customer_ID      0
# Order_Date       0
# Product          0
# Quantity         0
# Price            0
# Name             0
# Date_of_Birth    0
# Email            0
# Phone            0
# dtype: int64

# %%
print("\nMissing values in Customer_Info:")
print(cust.isnull().sum())
# Out:
# Missing values in Customer_Info:
# Customer_ID      0
# Name             0
# Date_of_Birth    1
# Email            1
# Phone            2
# dtype: int64

# %%
cust = cust.dropna(subset=['Phone', 'Email','Date_of_Birth'])
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    15-06-1985        john.doe@email.com
# 1         C002      Jane Smith    11/20/1990      jane.smith@email.com
# 2         C003   Alice Johnson    05-09-1988   alice.johnson@email.com
# 3         C004     Michael Lee    20-07-1987     michael.lee@email.com
# 5         C006    Robert Brown    1983-14-02    robert.brown@email.com
# 6         C007    Emily Wilson    19-07-1986    emily.wilson@email.com
# 7         C008    David Harris    25-05-1989    david.harris@email.com
# 9         C010     Paul Walker    30-08-1987     paul.walker@email.com
# 10        C002      Jane Smith    20-11-1990       janesmith@email.com
# 12        C012    James Miller    10-01-1993    james.miller@email.com
# 13        C013     Nancy Clark    14-07-1994     nancy.clark@email.com
# 14        C014     George King    03-11-1985     george.king@email.com
# ...

# %%
ord=pd.read_csv("/content/drive/MyDrive/Order_History.csv")
ord
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
cust=pd.read_csv("/content/drive/MyDrive/Customer_Info.csv")
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    15-06-1985        john.doe@email.com
# 1         C002      Jane Smith    11/20/1990      jane.smith@email.com
# 2         C003   Alice Johnson    05-09-1988   alice.johnson@email.com
# 3         C004     Michael Lee    20-07-1987     michael.lee@email.com
# 4         C005      Emma Davis    10-12-1992      emma.davis@email.com
# 5         C006    Robert Brown    1983-14-02    robert.brown@email.com
# 6         C007    Emily Wilson    19-07-1986    emily.wilson@email.com
# 7         C008    David Harris    25-05-1989    david.harris@email.com
# 8         C009  Linda Thompson           NaN  linda.thompson@email.com
# 9         C010     Paul Walker    30-08-1987     paul.walker@email.com
# 10        C002      Jane Smith    20-11-1990       janesmith@email.com
# 11        C011      Sarah Hall    22-04-1984                       NaN
# ...

# %%
cust = cust.drop_duplicates()

# %%
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    15-06-1985        john.doe@email.com
# 1         C002      Jane Smith    11/20/1990      jane.smith@email.com
# 2         C003   Alice Johnson    05-09-1988   alice.johnson@email.com
# 3         C004     Michael Lee    20-07-1987     michael.lee@email.com
# 4         C005      Emma Davis    10-12-1992      emma.davis@email.com
# 5         C006    Robert Brown    1983-14-02    robert.brown@email.com
# 6         C007    Emily Wilson    19-07-1986    emily.wilson@email.com
# 7         C008    David Harris    25-05-1989    david.harris@email.com
# 8         C009  Linda Thompson           NaN  linda.thompson@email.com
# 9         C010     Paul Walker    30-08-1987     paul.walker@email.com
# 10        C002      Jane Smith    20-11-1990       janesmith@email.com
# 11        C011      Sarah Hall    22-04-1984                       NaN
# ...

# %%
cust['Date_of_Birth'] = pd.to_datetime(cust['Date_of_Birth'], format='%d-%m-%Y', errors='coerce')

# %%
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    1985-06-15        john.doe@email.com
# 2         C003   Alice Johnson    1988-09-05   alice.johnson@email.com
# 3         C004     Michael Lee    1987-07-20     michael.lee@email.com
# 6         C007    Emily Wilson    1986-07-19    emily.wilson@email.com
# 7         C008    David Harris    1989-05-25    david.harris@email.com
# 9         C010     Paul Walker    1987-08-30     paul.walker@email.com
# 10        C002      Jane Smith    1990-11-20       janesmith@email.com
# 12        C012    James Miller    1993-01-10    james.miller@email.com
# 13        C013     Nancy Clark    1994-07-14     nancy.clark@email.com
# 14        C014     George King    1985-11-03     george.king@email.com
# 15        C015  Patricia Adams    1990-06-07  patricia.adams@email.com
# 17        C017    Angela Lewis    1987-12-29    angela.lewis@email.com
# ...

# %%
cust= cust.dropna()

# %%
cust
# Out:
#    Customer_ID            Name Date_of_Birth                     Email  \
# 0         C001        John Doe    1985-06-15        john.doe@email.com
# 2         C003   Alice Johnson    1988-09-05   alice.johnson@email.com
# 3         C004     Michael Lee    1987-07-20     michael.lee@email.com
# 6         C007    Emily Wilson    1986-07-19    emily.wilson@email.com
# 7         C008    David Harris    1989-05-25    david.harris@email.com
# 9         C010     Paul Walker    1987-08-30     paul.walker@email.com
# 10        C002      Jane Smith    1990-11-20       janesmith@email.com
# 12        C012    James Miller    1993-01-10    james.miller@email.com
# 13        C013     Nancy Clark    1994-07-14     nancy.clark@email.com
# 14        C014     George King    1985-11-03     george.king@email.com
# 15        C015  Patricia Adams    1990-06-07  patricia.adams@email.com
# 17        C017    Angela Lewis    1987-12-29    angela.lewis@email.com
# ...

# %%
ord
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
ord['Quantity'] = pd.to_numeric(ord['Quantity'], errors='coerce')
ord = ord.fillna(1)

# %%
ord
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O003        C003  22-01-2023  Headphones       2.0   150.00
# 3      O004        C004  05-02-2023      Tablet       1.0   300.00
# 4      O005        C005  15-02-2023      Camera       1.0   500.00
# 5      O006        C006  02-18-2023  Smartphone       1.0   800.00
# 6      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 7      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 8      O009        C009  10-03-2023      Tablet       1.0   350.00
# 9      O010        C010  03-15-2023      Camera       1.0   550.00
# 10     O011        C002  04-02-2023  Headphones       1.0   160.50
# 11     O012        C012  05-03-2023  Smartphone       1.0   850.00
# 12     O013        C013  06-10-2023      Laptop       1.0  1400.00
# ...

# %%
df=pd.merge(ord,cust, on='Customer_ID',how='inner')
from sklearn.preprocessing import MinMaxScaler

# %%
df
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
df1=pd.merge(ord,cust, on='Customer_ID',how='outer')
from sklearn.preprocessing import MinMaxScaler

# %%
df1
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
df2=pd.merge(ord,cust, on='Customer_ID',how='right')
from sklearn.preprocessing import MinMaxScaler

# %%
df2
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O003        C003  22-01-2023  Headphones       2.0   150.00
# 2      O004        C004  05-02-2023      Tablet       1.0   300.00
# 3      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 4      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 5      O010        C010  03-15-2023      Camera       1.0   550.00
# 6      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 7      O011        C002  04-02-2023  Headphones       1.0   160.50
# 8      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 9      O013        C013  06-10-2023      Laptop       1.0  1400.00
# 10     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 11     O015        C015  07-12-2023      Tablet       1.0   400.00
# 12     O017        C017  08/20/2023      Laptop       1.0  1500.75
# ...

# %%
df3=pd.merge(ord,cust, on='Customer_ID',how='left')
from sklearn.preprocessing import MinMaxScaler

# %%
df3
# Out:
#    Order_ID Customer_ID  Order_Date     Product  Quantity    Price  \
# 0      O001        C001  01-15-2023  Smartphone       1.0   700.00
# 1      O002        C002  01/20/2023      Laptop       1.0  1200.50
# 2      O011        C002  04-02-2023  Headphones       1.0   160.50
# 3      O003        C003  22-01-2023  Headphones       2.0   150.00
# 4      O004        C004  05-02-2023      Tablet       1.0   300.00
# 5      O007        C007  22-02-2023      Laptop       1.0  1200.50
# 6      O008        C008  03-01-2023  Smartwatch       2.0   200.00
# 7      O009        C009  10-03-2023      Tablet       1.0   350.00
# 8      O010        C010  03-15-2023      Camera       1.0   550.00
# 9      O012        C012  05-03-2023  Smartphone       1.0   850.00
# 10     O013        C013  06-10-2023      Laptop       1.0  1400.00
# 11     O014        C014  20-06-2023  Smartwatch       3.0   250.00
# 12     O015        C015  07-12-2023      Tablet       1.0   400.00
# ...

# %%
df.to_csv("/content/drive/MyDrive/Order_History.csv", index=False)
